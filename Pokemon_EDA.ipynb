# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('pokemon.csv', index_col=0, encoding='ISO-8859–1')
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
# Improved Scatterplot Tutorial
sns.lmplot(x="Attack", y="Defense", data=df, fit_reg=False, hue='Stage')

# MatPlotLib Customization
plt.ylim(0, None)
plt.xlim(0, None)

# Creating a Cool Box Plot
stats_df = df.drop(["Total", "Stage", "Legendary"], axis=1)
sns.boxplot(data=stats_df)

# Tuning our color palette for the data
pokemon_palette = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]
sns.set_palette(pokemon_palette)

# Creating a Neat Violin Plot
sns.violinplot(x="Type 1", y="Attack", data=df, hue="Type 1", legend=False)

# Creating a Swarm Plot
plt.figure(figsize=(10,6))
sns.swarmplot(x="Type 1", y="Attack", data=df, size=5)

# Creating a Overlayed Violin-Swarm Plot
plt.figure(figsize=(10,6))
sns.violinplot(x="Type 1", y="Attack", data=df, inner=None)
sns.swarmplot(x="Type 1", y="Attack", data=df, color='k', alpha=0.7)

# Creating a correlation heatmap of stats
numeric_cols = stats_df.select_dtypes(include=np.number)
corr = numeric_cols.corr()
sns.heatmap(corr)

# Creating a histogram
sns.histplot(df.Attack)

# Creating a Bar Plot
sns.countplot(x="Type 1", data=df)


# Creating a Factor Plot
sns.catplot(x="Type 1", y="Attack", data=df, hue="Stage", col="Stage", kind="swarm", legend=False)

# Creating a Density Plot
sns.kdeplot(df.Attack, df.Defense)

# Creating a Joint Distribution Plot
sns.jointplot(x="Attack", y="Defense", data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 59
#      56 sns.catplot(x="Type 1", y="Attack", data=df, hue="Stage", col="Stage", kind="swarm", legend=False)
#      58 # Creating a Density Plot
# ---> 59 sns.kdeplot(df.Attack, df.Defense)
#      61 # Creating a Joint Distribution Plot
#      62 sns.jointplot(x="Attack", y="Defense", data=df)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given
